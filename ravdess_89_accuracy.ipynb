# %% [markdown]
# <a href="https://www.kaggle.com/code/hamadismail/ravdess-humanemotionrecognition-3d-cnn?scriptVersionId=147955902" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Data Preparation

# %%
import os
# Root = "/kaggle/input/d/hamadismail/ravdesslite/ravdesslite/"
Root = "/kaggle/input/ravdess/"
os.chdir(Root)

# %% [markdown]
# # Importing Libraries

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##  <center> 1. Ravdess Dataframe <center>

# %%
ravdess_directory_list = os.listdir(Root)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Root + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Root + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#    Emotions                                               Path
# 0  surprise  /kaggle/input/ravdess/Actor_02/03-01-08-01-01-...
# 1   neutral  /kaggle/input/ravdess/Actor_02/03-01-01-01-01-...
# 2   disgust  /kaggle/input/ravdess/Actor_02/03-01-07-02-01-...
# 3   disgust  /kaggle/input/ravdess/Actor_02/03-01-07-01-01-...
# 4   neutral  /kaggle/input/ravdess/Actor_02/03-01-01-01-02-...

# %%
# creating Dataframe using ravdees dataframes we created so far.
data_path = pd.concat([Ravdess_df], axis = 0)
data_path.to_csv("/kaggle/working/data_path.csv",index=False)
# data_path.head()

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sr=22050, n_steps=2):
    return librosa.effects.pitch_shift(data, sr=sr, n_steps=n_steps)

# taking any example and checking for techniques.
path = np.array(data_path.Path)[1]
data, sample_rate = librosa.load(path)

# %%
# def extract_features(data):
#     # ZCR
#     result = np.array([])
#     zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
#     result=np.hstack((result, zcr)) # stacking horizontally

#     # Chroma_stft
#     stft = np.abs(librosa.stft(data))
#     chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
#     result = np.hstack((result, chroma_stft)) # stacking horizontally

#     # MFCC
#     mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
#     result = np.hstack((result, mfcc)) # stacking horizontally

#     # Root Mean Square Value
#     rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
#     result = np.hstack((result, rms)) # stacking horizontally

#     # MelSpectogram
#     mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
#     result = np.hstack((result, mel)) # stacking horizontally
    
#     return result

# def get_features(path):
#     # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
#     data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
#     # without augmentation
#     res1 = extract_features(data)
#     result = np.array(res1)
    
#     # data with noise
#     noise_data = noise(data)
#     res2 = extract_features(noise_data)
#     result = np.vstack((result, res2)) # stacking vertically
    
#     # data with shift
#     shift_data = shift(data)
#     res3 = extract_features(shift_data)
#     result = np.vstack((result, res3)) # stacking vertically
    
#     # data with stretching and pitching
#     new_data = stretch(data)
#     data_stretch_pitch = pitch(new_data, sample_rate)
#     res4 = extract_features(data_stretch_pitch)
#     result = np.vstack((result, res4)) # stacking vertically
    
#     return result

# %%
def extract_features(data):
    # ZCR
#     result = np.array([])

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=13).T, axis=0)
    mfccs = librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=13)
    
    # If the resulting MFCC matrix has fewer frames than n_frames, you can pad it.
    if mfccs.shape[1] < 108:
        pad_width = 108 - mfccs.shape[1]
        mfccs = np.pad(mfccs, ((0, 0), (0, pad_width)), mode='constant')

    # If the resulting MFCC matrix has more frames than n_frames, you can truncate it.
    if mfccs.shape[1] > 108:
        mfccs = mfccs[:, :108]
    
#     mfccs = mfccs.flatten()
#     result = np.hstack((result, mfcc)) # stacking horizontally 
    return mfccs

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data) # 13
    result = np.array(res1) # (13, )

    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data) # (13, )
    result = np.vstack((result, res2)) # stacking vertically (2, 13)
    
    result = result.reshape(2, 13, 108)
    
    return result

# %%
X, Y = [], []

for path, emotion in zip(data_path.Path, data_path.Emotions):
    feature = get_features(path)

    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)

# %%
print(feature.shape)
print(ele.shape)
# Out:
# (2, 13, 108)
# (13, 108)

# %%
X = np.array(X)
Y = np.array(Y)

print(X.shape, len(X), len(Y))
# Out:
# (2880, 13, 108) 2880 2880

# %%
X = X.reshape(120,13,108)
# X = X[:, :, np.newaxis]

# %%
print(X.shape)
# Out:
# (120, 128, 108, 2)

# %%
# print(X)

# %%
num_samples = len(X)
num_time_steps = X[0].shape[0]  # Assuming all features have the same length
num_frequency_bins = X[0].shape[1]  # 1D audio data has only one frequency bin
width = 1#X[0].shape[2]

print("Number of samples:", num_samples)
print("Number of time steps:", num_time_steps)
print("Number of frequency bins:", num_frequency_bins)
print("Number of frequency bins:", width)
# Out:
# Number of samples: 2880
# Number of time steps: 13
# Number of frequency bins: 108
# Number of frequency bins: 1

# %%
# print(X)

# %%
# Flatten the 3D feature array into 2D
X_flattened = X.reshape(X.shape[0], -1)

Features = pd.DataFrame(X_flattened)
Features['labels'] = Y
Features.to_csv('/kaggle/working/features.csv', index=False)
Features.head()
# Out:
#             0           1           2           3           4           5  \
# 0 -769.166016 -766.929565 -727.547607 -674.543884 -636.408508 -605.675110
# 1 -547.844397 -514.690429 -511.343873 -504.685376 -504.478581 -502.084286
# 2 -829.434021 -829.434021 -829.434021 -829.434021 -829.434021 -829.434021
# 3 -579.785457 -543.312532 -540.017114 -541.151369 -541.990948 -542.608750
# 4 -769.621765 -769.621765 -769.621765 -769.621765 -769.621765 -769.621765
#
#             6           7           8           9  ...      1395      1396  \
# 0 -588.955139 -584.948059 -579.149475 -579.098633  ...  3.350791  2.408971
# 1 -495.667704 -493.687339 -491.484898 -488.175209  ... -0.031771 -0.735876
# 2 -829.431396 -829.263977 -829.434021 -829.434021  ... -0.324908 -2.492361
# 3 -543.586827 -544.166478 -540.976599 -541.164214  ...  2.275640  0.233286
# 4 -769.621765 -769.621765 -769.621765 -769.621765  ... -7.491926 -9.273613
#
#        1397      1398      1399      1400       1401       1402       1403  \
# 0  1.070436  1.949592  2.393641  3.410163   3.353764   1.145004  -1.827868
# 1  1.665439 -0.739839  4.414142  4.068822   0.295064  -4.083330  -8.053745
# 2  3.089616  4.551142  2.925217  4.748022   4.639663   7.311019   2.973966
# 3 -2.927472 -1.992728 -0.834490  1.789573  -0.200490  -0.364183   7.132486
# 4 -5.460621 -4.981466 -4.197380 -8.274688 -12.788338 -18.970175 -14.331495
#
#      labels
# 0  surprise
# 1  surprise
# 2   neutral
# 3   neutral
# 4   disgust
#
# [5 rows x 1405 columns]

# %% [markdown]
# ## Data Preparation
#
# - As of now we have extracted the data, now we need to normalize and split our data for training and testing.

# %%
# X = Features.iloc[: ,:-1].values
X = np.array(Features.iloc[:, :-1].values).reshape(num_samples, num_time_steps, num_frequency_bins, width)
Y = Features['labels'].values

# %%
from sklearn.preprocessing import OneHotEncoder
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, test_size=0.2, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((2304, 13, 108, 1), (2304, 8), (576, 13, 108, 1), (576, 8))

# %%
from sklearn.preprocessing import StandardScaler

# Reshape the data to 2D
x_train_2d = x_train.reshape(x_train.shape[0], -1)
x_test_2d = x_test.reshape(x_test.shape[0], -1)

# Apply StandardScaler to the 2D data
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_2d)
x_test_scaled = scaler.transform(x_test_2d)

# Reshape the scaled data back to 3D
x_train = x_train_scaled.reshape(x_train.shape[0], num_time_steps, num_frequency_bins, width)
x_test = x_test_scaled.reshape(x_test.shape[0], num_time_steps, num_frequency_bins, width)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((2304, 13, 108, 1), (2304, 8), (576, 13, 108, 1), (576, 8))

# %% [markdown]
# ## Modelling

# %%
import keras
from keras.layers import Input, Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, Sequential
import numpy as np

# Define the model
model = Sequential()

# First Conv3D layer
model.add(Conv3D(64, kernel_size=(3, 3, 1), strides=(1, 1, 1), padding='same', activation='relu', input_shape=(num_time_steps, num_frequency_bins, 1, 1)))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 1), strides=(2, 2, 1)))

# Second Conv3D layer
model.add(Conv3D(128, kernel_size=(3, 3, 1), strides=(1, 1, 1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 1), strides=(2, 2, 1)))

# Third Conv3D layer
model.add(Conv3D(256, kernel_size=(3, 3, 1), strides=(1, 1, 1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 1), strides=(2, 2, 1)))

# Flatten layer
model.add(Flatten())

# Fully connected layers
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_43 (Conv3D)          (None, 13, 108, 1, 64)    640
#
#  batch_normalization_43 (Bat  (None, 13, 108, 1, 64)   256
#  chNormalization)
#
#  max_pooling3d_43 (MaxPoolin  (None, 6, 54, 1, 64)     0
#  g3D)
#
#  conv3d_44 (Conv3D)          (None, 6, 54, 1, 128)     73856
#
#  batch_normalization_44 (Bat  (None, 6, 54, 1, 128)    512
#  chNormalization)
#
#  max_pooling3d_44 (MaxPoolin  (None, 3, 27, 1, 128)    0
#  g3D)
#
#  conv3d_45 (Conv3D)          (None, 3, 27, 1, 256)     295168
#
#  batch_normalization_45 (Bat  (None, 3, 27, 1, 256)    1024
#  chNormalization)
#
#  max_pooling3d_45 (MaxPoolin  (None, 1, 13, 1, 256)    0
#  g3D)
#
#  flatten_13 (Flatten)        (None, 3328)              0
#
#  dense_26 (Dense)            (None, 64)                213056
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 585,032
# Trainable params: 584,136
# Non-trainable params: 896
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/100
# 36/36 [==============================] - 3s 20ms/step - loss: 2.1699 - accuracy: 0.2122 - val_loss: 2.5628 - val_accuracy: 0.1910 - lr: 0.0010
# Epoch 2/100
# 36/36 [==============================] - 0s 14ms/step - loss: 1.8357 - accuracy: 0.2695 - val_loss: 4.1933 - val_accuracy: 0.1719 - lr: 0.0010
# Epoch 3/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.6587 - accuracy: 0.3477 - val_loss: 4.4069 - val_accuracy: 0.1788 - lr: 0.0010
# Epoch 4/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.5691 - accuracy: 0.3859 - val_loss: 3.7303 - val_accuracy: 0.1389 - lr: 0.0010
# Epoch 5/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.3832 - accuracy: 0.4388 - val_loss: 2.6382 - val_accuracy: 0.1424 - lr: 0.0010
# Epoch 6/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.3290 - accuracy: 0.4614 - val_loss: 2.1936 - val_accuracy: 0.2413 - lr: 0.0010
# Epoch 7/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.2011 - accuracy: 0.5148 - val_loss: 1.8787 - val_accuracy: 0.3264 - lr: 0.0010
# Epoch 8/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.1214 - accuracy: 0.5573 - val_loss: 1.7227 - val_accuracy: 0.3976 - lr: 0.0010
# Epoch 9/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0629 - accuracy: 0.5664 - val_loss: 1.6247 - val_accuracy: 0.4010 - lr: 0.0010
# Epoch 10/100
# 36/36 [==============================] - 0s 13ms/step - loss: 1.0157 - accuracy: 0.5916 - val_loss: 1.3161 - val_accuracy: 0.5312 - lr: 0.0010
# Epoch 11/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.9085 - accuracy: 0.6298 - val_loss: 1.1098 - val_accuracy: 0.6076 - lr: 0.0010
# Epoch 12/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.8602 - accuracy: 0.6645 - val_loss: 1.2995 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 13/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7689 - accuracy: 0.7027 - val_loss: 0.9667 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 14/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.7068 - accuracy: 0.7274 - val_loss: 0.9299 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 15/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.6733 - accuracy: 0.7240 - val_loss: 0.9518 - val_accuracy: 0.6858 - lr: 0.0010
# Epoch 16/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5710 - accuracy: 0.7734 - val_loss: 0.9622 - val_accuracy: 0.6823 - lr: 0.0010
# Epoch 17/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.5428 - accuracy: 0.7826 - val_loss: 0.6569 - val_accuracy: 0.7847 - lr: 0.0010
# Epoch 18/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4953 - accuracy: 0.8008 - val_loss: 0.7777 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 19/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4533 - accuracy: 0.8203 - val_loss: 0.8605 - val_accuracy: 0.7431 - lr: 0.0010
# Epoch 20/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.4555 - accuracy: 0.8220 - val_loss: 0.7225 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 21/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3795 - accuracy: 0.8572 - val_loss: 0.7912 - val_accuracy: 0.7622 - lr: 0.0010
# Epoch 22/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3791 - accuracy: 0.8455 - val_loss: 0.8473 - val_accuracy: 0.7274 - lr: 0.0010
# Epoch 23/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.3215 - accuracy: 0.8802 - val_loss: 0.8159 - val_accuracy: 0.7743 - lr: 0.0010
# Epoch 24/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.3307 - accuracy: 0.8663 - val_loss: 0.5982 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 25/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2531 - accuracy: 0.9002 - val_loss: 0.7253 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 26/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2461 - accuracy: 0.8954 - val_loss: 0.7248 - val_accuracy: 0.8142 - lr: 0.0010
# Epoch 27/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2458 - accuracy: 0.9054 - val_loss: 0.6681 - val_accuracy: 0.8073 - lr: 0.0010
# Epoch 28/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2874 - accuracy: 0.8867 - val_loss: 0.8111 - val_accuracy: 0.7726 - lr: 0.0010
# Epoch 29/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2218 - accuracy: 0.9136 - val_loss: 0.7963 - val_accuracy: 0.8003 - lr: 0.0010
# Epoch 30/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2235 - accuracy: 0.9145 - val_loss: 0.7179 - val_accuracy: 0.8316 - lr: 0.0010
# Epoch 31/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.2117 - accuracy: 0.9249 - val_loss: 0.7294 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 32/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1902 - accuracy: 0.9262 - val_loss: 0.6511 - val_accuracy: 0.8351 - lr: 0.0010
# Epoch 33/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1476 - accuracy: 0.9440 - val_loss: 0.7539 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 34/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1412 - accuracy: 0.9453 - val_loss: 0.7615 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 35/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1433 - accuracy: 0.9470 - val_loss: 0.6122 - val_accuracy: 0.8351 - lr: 0.0010
# Epoch 36/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1480 - accuracy: 0.9484 - val_loss: 0.7388 - val_accuracy: 0.8073 - lr: 0.0010
# Epoch 37/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.1312 - accuracy: 0.9531 - val_loss: 0.6313 - val_accuracy: 0.8576 - lr: 4.0000e-04
# Epoch 38/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0887 - accuracy: 0.9679 - val_loss: 0.5889 - val_accuracy: 0.8715 - lr: 4.0000e-04
# Epoch 39/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0836 - accuracy: 0.9679 - val_loss: 0.6924 - val_accuracy: 0.8524 - lr: 4.0000e-04
# Epoch 40/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0782 - accuracy: 0.9727 - val_loss: 0.5854 - val_accuracy: 0.8681 - lr: 4.0000e-04
# Epoch 41/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0721 - accuracy: 0.9740 - val_loss: 0.5964 - val_accuracy: 0.8715 - lr: 4.0000e-04
# Epoch 42/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0683 - accuracy: 0.9740 - val_loss: 0.5760 - val_accuracy: 0.8819 - lr: 4.0000e-04
# Epoch 43/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 0.5852 - val_accuracy: 0.8819 - lr: 4.0000e-04
# Epoch 44/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0595 - accuracy: 0.9787 - val_loss: 0.7034 - val_accuracy: 0.8646 - lr: 4.0000e-04
# Epoch 45/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0678 - accuracy: 0.9753 - val_loss: 0.5614 - val_accuracy: 0.8802 - lr: 4.0000e-04
# Epoch 46/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0546 - accuracy: 0.9787 - val_loss: 0.5600 - val_accuracy: 0.8767 - lr: 1.6000e-04
# Epoch 47/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0566 - accuracy: 0.9818 - val_loss: 0.5730 - val_accuracy: 0.8837 - lr: 1.6000e-04
# Epoch 48/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0378 - accuracy: 0.9852 - val_loss: 0.5550 - val_accuracy: 0.8854 - lr: 1.6000e-04
# Epoch 49/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.9818 - val_loss: 0.5740 - val_accuracy: 0.8854 - lr: 1.6000e-04
# Epoch 50/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0474 - accuracy: 0.9813 - val_loss: 0.6107 - val_accuracy: 0.8819 - lr: 1.6000e-04
# Epoch 51/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0457 - accuracy: 0.9826 - val_loss: 0.5998 - val_accuracy: 0.8854 - lr: 6.4000e-05
# Epoch 52/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0468 - accuracy: 0.9826 - val_loss: 0.5991 - val_accuracy: 0.8837 - lr: 6.4000e-05
# Epoch 53/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0395 - accuracy: 0.9848 - val_loss: 0.5973 - val_accuracy: 0.8854 - lr: 2.5600e-05
# Epoch 54/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0405 - accuracy: 0.9874 - val_loss: 0.5933 - val_accuracy: 0.8872 - lr: 2.5600e-05
# Epoch 55/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0416 - accuracy: 0.9874 - val_loss: 0.5921 - val_accuracy: 0.8872 - lr: 1.0240e-05
# Epoch 56/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0476 - accuracy: 0.9818 - val_loss: 0.5920 - val_accuracy: 0.8854 - lr: 1.0240e-05
# Epoch 57/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0504 - accuracy: 0.9800 - val_loss: 0.5920 - val_accuracy: 0.8854 - lr: 4.0960e-06
# Epoch 58/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0432 - accuracy: 0.9818 - val_loss: 0.5922 - val_accuracy: 0.8872 - lr: 4.0960e-06
# Epoch 59/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0412 - accuracy: 0.9861 - val_loss: 0.5927 - val_accuracy: 0.8872 - lr: 1.6384e-06
# Epoch 60/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0510 - accuracy: 0.9805 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.6384e-06
# Epoch 61/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.5926 - val_accuracy: 0.8889 - lr: 6.5536e-07
# Epoch 62/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.9831 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 6.5536e-07
# Epoch 63/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 2.6214e-07
# Epoch 64/100
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0490 - accuracy: 0.9813 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 2.6214e-07
# Epoch 65/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0542 - accuracy: 0.9792 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0486e-07
# Epoch 66/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0486e-07
# Epoch 67/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0426 - accuracy: 0.9835 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 68/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0512 - accuracy: 0.9831 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 69/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0383 - accuracy: 0.9852 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 70/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0413 - accuracy: 0.9831 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 71/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0437 - accuracy: 0.9831 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 72/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0425 - accuracy: 0.9839 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 73/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0415 - accuracy: 0.9839 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 74/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0472 - accuracy: 0.9831 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 75/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0472 - accuracy: 0.9835 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 76/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0401 - accuracy: 0.9865 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 77/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0446 - accuracy: 0.9826 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 78/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0463 - accuracy: 0.9835 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 79/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0444 - accuracy: 0.9831 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 80/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0531 - accuracy: 0.9800 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 81/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0464 - accuracy: 0.9831 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 82/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0478 - accuracy: 0.9822 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 83/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0424 - accuracy: 0.9861 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 84/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0502 - accuracy: 0.9805 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 85/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0500 - accuracy: 0.9809 - val_loss: 0.5926 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 86/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0404 - accuracy: 0.9870 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 87/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0463 - accuracy: 0.9831 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 88/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0558 - accuracy: 0.9783 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 89/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0498 - accuracy: 0.9805 - val_loss: 0.5925 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 90/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0477 - accuracy: 0.9822 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 91/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0431 - accuracy: 0.9818 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 92/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0506 - accuracy: 0.9826 - val_loss: 0.5924 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 93/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0402 - accuracy: 0.9857 - val_loss: 0.5927 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 94/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0456 - accuracy: 0.9839 - val_loss: 0.5928 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 95/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0528 - accuracy: 0.9800 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 96/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0430 - accuracy: 0.9831 - val_loss: 0.5920 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 97/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0564 - accuracy: 0.9813 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 98/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0536 - accuracy: 0.9796 - val_loss: 0.5922 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 99/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0455 - accuracy: 0.9813 - val_loss: 0.5923 - val_accuracy: 0.8889 - lr: 1.0000e-07
# Epoch 100/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0419 - accuracy: 0.9818 - val_loss: 0.5925 - val_accuracy: 0.8872 - lr: 1.0000e-07

# %%
import matplotlib.pyplot as plt

print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5925 - accuracy: 0.8872
# Accuracy of our model on test data :  88.71527910232544 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 18/18 [==============================] - 0s 3ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            happy         angry
# 1              sad           sad
# 2             calm          calm
# 3             fear          fear
# 4             calm          calm
# 5          disgust       disgust
# 6          disgust       disgust
# 7            angry         angry
# 8          neutral       neutral
# 9              sad           sad

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns


cm = confusion_matrix(y_test, y_pred)
# plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.93      0.91      0.92        74
#         calm       0.88      0.96      0.92        75
#      disgust       0.94      0.88      0.91        91
#         fear       0.88      0.79      0.84        77
#        happy       0.82      0.92      0.87        63
#      neutral       0.89      0.89      0.89        35
#          sad       0.87      0.80      0.84        76
#     surprise       0.88      0.95      0.92        85
#
#     accuracy                           0.89       576
#    macro avg       0.89      0.89      0.89       576
# weighted avg       0.89      0.89      0.89       576
